# %% [raw]
# # Python for SAS Users

# %% [markdown]
# ## Chapter orginization
#
# These chapters are meant to be read in order as they start with foundational concepts used to build up more complex ideas.
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%200%20--%20Frontispiece.ipynb">00. Motivation </a>
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%201%20--%20Introduction.ipynb">01.  Introduction (This chapter) </a>
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%202%20--%20Data%20Structures.ipynb">02. Data Sctructures </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.1%20--%20Data%20Structures.ipynb#02.1%20list" a>02.1 list </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.2%20--%20Data%20Structures.ipynb#02.2%20Indexing" a>02.2 indexing </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.3%20--%20Data%20Structures.ipynb#02.3%20tuple" a>02.3 tuple </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.4%20--%20Data%20Structures.ipynb#02.4%20dictionary" a>02.4 dictionary </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.5%20--%20Data%20Structures.ipynb#02.5%20sequences" a>02.5 sequences </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.6%20--%20Data%20Structures.ipynb#02.6#20set" a>02.6 set </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2002.7%20--%20Data%20Structures.ipynb#02.7#20Resources" a>02.7 Resources</a>
#
# <a href="https://github.com/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003%20%20--%20Data%20Types%20and%20Formatting.ipynb">03. Data Types and Formatting </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003.1%20%20--%20Data%20Types%20and%20Formatting.ipynb#03.1%20Numerics">03.1 Numerics </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003.2%20%20--%20Data%20Types%20and%20Formatting.ipynb#03.2%20Boolean">03.2 Boolean </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003.3%20%20--%20Data%20Types%20and%20Formatting.ipynb#03.3%20Strings">03.3 Strings </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003%20%20--%20Data%20Types%20and%20Formatting.ipynb#03.4%20String-Slicing">03.4 String Slicing </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003.5%20%20--%20Data%20Types%20and%20Formatting.ipynb#03.5%20String-Formatting">03.5 String Formatting </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2003.6%20%20--%20Data%20Types%20and%20Formatting.ipynb#03.6%20Resources">03.6 Resources </a>
#
# <a href="https://github.com/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004%20--%20Pandas%2C%20Part%201.ipynb">04.  Pandas, Part 1 </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004.1%20--%20Pandas%2C%20Part%201.ipynb#4.1%20DataFrames"> 04.1 DataFrames </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%204.2%20--%20Pandas%2C%20Part%201.ipynb#04.2%20pd.read_csv()"> 04.2 Read .csv files </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004.3%20--%20Pandas%2C%20Part%201.ipynb#04.3%20Insepction"> 04.3 Inspection </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004.4%20--%20Pandas%2C%20Part%201.ipynb#04.3%20Handling-Missing-Data"> 04.4 Handling Missing Data </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004.5%20--%20Pandas%2C%20Part%201.ipynb#04.5%20Missing-Value-Identification"> 04.5 Missing Data Detection</a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004.6%20--%20Pandas%2C%20Part%201.ipynb#04.6%20Missing-Value-Replacement"> 04.6 Missing Value Replacement </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2004.7%20--%20Pandas%2C%20Part%201.ipynb#04.7%20Resources"> 04.7 Resources </a>
#
# <a href="https://github.com/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2005%20--%20Pandas%2C%20Part%201.ipynb">05. Pandas, Part 2 </a>
#
#         a. Slicing
#         b. Dicing
#         c. Subsetting
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipyn">06.  Understanding Indexes, Part 1 </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#Indicies"> Indicies </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#.iloc-Indexer"> .iloc indexer </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#.loc-Indexer"> .loc indexer </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#Mixing-.loc-Indexer-with-Boolean-Operators"> Mixing .loc indexer with Boolean Operations </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#Altering-DataFrame-values-using-the-.loc-indexer"> Altering DataFrame values using the .loc indexer </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#.ix-Indexer"> .ix indexer </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#Indexing-Issues"> Indexing Issues </a>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2006%20--%20Understanding%20Indexes.ipynb#Resources"> Resources </a>
#
#     7.  Understanding Indexes, Part 2
#         a. Hierarchical Indexing
#         b. 'Flattening, 'Roll-ups', and Pivots
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2008%20--%20Date%2C%20Time%2C%20and%20%20Timedelta%20Objects.ipynb">08.  Date, Time, and Timedelta Objects </a>
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2009%20--%20Panda%20Time%20Series%20and%20Date%20Handling.ipynb">09.  Panda Time Series and Date Handling </a>
#
#     10. Flow Control
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/blob/master/Chapter%2011%20--%20Panda%20Readers.ipynb"> 11. Panda Readers </a>
#
#     12. Data Handling
#
#     13. Data Analysis

# %% [raw]
# ## Navigation
#
# <a href="http://nbviewer.jupyter.org/github/RandyBetancourt/PythonForSASUsers/tree/master/"> Return to Chapter List </a>
